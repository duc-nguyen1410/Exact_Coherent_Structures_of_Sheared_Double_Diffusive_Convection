# %% [markdown]
# ## Plot bifurcation diagram with stability
# - Solid line: stable
# - Dashed line: unstable (real part > $10^{-6}$)

# %%
from func import *
fontsize = 16
plt.figure(figsize=(6, 3))


print("get E2 bifurcation")
Ra, Sh, instability = np.load("Data/Equilibrium_3D_effect/continuation_Ly0.5_E2_Ra_Sh.npz").values()
segments = separate_into_segments(Ra, Sh, instability)
plot_stability_bifurcation(segments,'E2','g',"dashed")

print("get E2-3D bifurcation")
Ra, Sh, instability = np.load("Data/Equilibrium_3D_effect/continuation_Ly0.5_E2-3D_Ra_Sh.npz").values()
segments = separate_into_segments(Ra, Sh, instability)
plot_stability_bifurcation(segments,'E2-3D','tab:blue')
Ra, Sh, instability = np.load("Data/Equilibrium_3D_effect/continuation_Ly0.5_C24-3D_Ra_Sh.npz").values()
segments = separate_into_segments(Ra, Sh, instability)
plot_stability_bifurcation(segments,'C24-3D','k')

print("get E4 bifurcation")
Ra, Sh, instability = np.load("Data/Equilibrium_3D_effect/continuation_Ly0.5_E4_Ra_Sh.npz").values()
segments = separate_into_segments(Ra, Sh, instability)
plot_stability_bifurcation(segments,'E4','gray')

print("get E4-3D bifurcation")
Ra, Sh, instability = np.load("Data/Equilibrium_3D_effect/continuation_Ly0.5_E4-3D_Ra_Sh.npz").values()
segments = separate_into_segments(Ra, Sh, instability)
plot_stability_bifurcation(segments,'E4-3D','tab:orange')


plt.xlabel(r'$Ra$', fontsize=fontsize)
plt.ylabel(r'$Sh$', fontsize=fontsize)
plt.xticks([0, 5000,10000, 15000,20000],fontsize=fontsize)

plt.xlim([0, 20000])
# plt.ylim([1, 3])
plt.yticks([1,2,3,4,5],fontsize=fontsize)
# plt.ylim([0.9, 3])
# plt.xscale('linear')
plt.legend(frameon=False)

plt.savefig('Data/Equilibrium_3D_effect/3D_bifurcation_diagram_RaSh.png', dpi=300, bbox_inches='tight')

plt.show()
plt.close()
# Out:
# get E2 bifurcation
# get E2-3D bifurcation
# get E4 bifurcation
# get E4-3D bifurcation

# %% [markdown]
# # figure 18c is plotted by Paraview
