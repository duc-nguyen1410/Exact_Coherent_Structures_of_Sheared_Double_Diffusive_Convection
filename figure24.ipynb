# %% [markdown]
# Picture 22 is generated by Matlab that is saved at folder `"LinearStabilityAnalysis/Vertically_Periodic_SDDC_at_infinite_Pr/FullSDDC_Pr=10"` and `"LinearStabilityAnalysis/Vertically_Periodic_SDDC_at_infinite_Pr/ReducedSDDC_Pr=10"`
