# %% [markdown]
# ## Plot time period of PO1 and PO2

# %%
from func import *
frontsize = 16

plt.figure(figsize=(4, 3))

print("get PO1 period")
Ra, TPO1 = np.load("Data/PeriodicOrbits/continuation_PO1_Ra_Tpo.npz",allow_pickle=True).values()
isunstable = [True] * len(TPO1)
segments = separate_into_segments(Ra,TPO1,isunstable)
plot_stability_bifurcation(segments,'PO1','tab:brown','solid')

print("get PO2 period")
Ra, TPO2 = np.load("Data/PeriodicOrbits/continuation_PO2_Ra_Tpo.npz",allow_pickle=True).values()
isunstable = [True] * len(TPO2)
segments = separate_into_segments(Ra,TPO2,isunstable)
plot_stability_bifurcation(segments,'PO2','m','solid')
############################ Periodic orbits #############################

plt.xlabel(r'$Ra$', fontsize=frontsize)
plt.ylabel(r'$T_{po}$', fontsize=frontsize)
plt.xticks(fontsize=frontsize)
plt.yticks(fontsize=frontsize)
# plt.xlim([27000, 60000])
# plt.xscale('linear')
plt.legend()
plt.savefig('Data/PeriodicOrbits/Ra_Tpo.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# get PO1 period
# get PO2 period
