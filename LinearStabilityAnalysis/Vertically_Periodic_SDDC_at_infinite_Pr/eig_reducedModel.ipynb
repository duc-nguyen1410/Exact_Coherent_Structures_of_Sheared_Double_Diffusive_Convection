# %% [markdown]
# #

# %% [markdown]
# # Reduced model of Radko JFM (2016)

# %% [markdown]
# This function conpute eigenvalue of linear problem of reduced equation of eq 4.1 in Radko paper. Here I cut off the inertial terms in momentum, implying the infinite Prandtl number limit.
