# %% [markdown]
# # Plot properties of PO1 at Ra = 40000

# %%
from func import *

plot_JtNu = False
plot_JcSh = True


fontsize = 16

# PO1, T~43->44
start=0
end = -200
T=44 # 43.74


############### plot Jt vs Nu ###############
[_,Jt_po]=readdata("Data/Ra40000/PO1/energy.asc",16)
[_,Nu_po]=readdata("Data/Ra40000/PO1/energy.asc",17)
[_,Jt_eq]=readdata("Data/Ra40000/S1_up/fieldconverge.asc",15)
[_,Nu_eq]=readdata("Data/Ra40000/S1_up/fieldconverge.asc",16)

Jt_po = np.append(Jt_po, Jt_po[0]) # make closed loop
Nu_po = np.append(Nu_po, Nu_po[0])


plt.figure(figsize=(3, 3))
plt.plot(Jt_po,Nu_po,marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel(r'$J_T$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.savefig('Data/Ra40000/PO1/PO1_JtNu.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(3, 3))
# plot single period T of PO
plt.plot(Jt_po,Nu_po,marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
# plot eq point
plt.scatter(Jt_eq[-1],Nu_eq[-1],marker='o',color='r',label='E1',zorder=3)
ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel(r'$J_T$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.savefig('Data/Ra40000/PO1/PO1_JtNu.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()



# x_eq = y_eq = Nusselt("highPr/Pr7/Ra40000/S1_up/tbest.nc")

[_,Js_po]=readdata("Data/Ra40000/PO1/energy.asc",21)
[_,Sh_po]=readdata("Data/Ra40000/PO1/energy.asc",22)
[_,Js_eq]=readdata("Data/Ra40000/S1_up/fieldconverge.asc",20)
[_,Sh_eq]=readdata("Data/Ra40000/S1_up/fieldconverge.asc",21)
    
# x_eq = y_eq = Nusselt("highPr/Pr7/Ra40000/S1_up/sbest.nc")


# plot single period T of PO
plt.plot(Jt_po,Nu_po,marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
# plot eq point
plt.scatter(Jt_eq[-1],Nu_eq[-1],marker='o',color='r',label='E1',zorder=3)


# plt.scatter(x_po[-2],y_po[-2],marker='*',color='k',zorder=3) # min Sh
# plt.scatter(x_po[9],y_po[9],marker='*',color='k',zorder=3) # max Nu
# plt.scatter(x_po[16],y_po[16],marker='*',color='k',zorder=3) # max Sh
# plt.scatter(x_po[36],y_po[36],marker='*',color='k',zorder=3) # min Nu

ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

if plot_JtNu:
    plt.xlabel(r'$J_T$', fontsize=fontsize)
    plt.ylabel(r'$Nu$', fontsize=fontsize)
    plt.savefig('Data/Ra40000/PO1/PO1_JtNu.png', dpi=300, bbox_inches='tight')
elif plot_JcSh:
    plt.xlabel(r'$J_S$', fontsize=fontsize)
    plt.ylabel(r'$Sh$', fontsize=fontsize)
    plt.legend()
    # plt.xlim([2.8215,2.823])
    # plt.xticks(fontsize=fontsize+2)
    # plt.yticks(fontsize=fontsize+2)
    plt.savefig('Data/Ra40000/PO1/PO1_EQ_JcSh.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
from func import *
fontsize = 16
plt.figure(figsize=(4, 3))
# PO1, T~43->44
T=44 # 43.74
start=0
end = -1

[time,Nu]=readdata("highPr/Pr7/Ra40000/PO1/energy.asc",17)
plt.plot(time[start:end],Nu[start:end],'k', linewidth= '1', label=r'$Nu$',zorder=2)
[time,Sh]=readdata("highPr/Pr7/Ra40000/PO1/energy.asc",22)
plt.plot(time[start:end],Sh[start:end],'r', linewidth= '1', label=r'$Sh$',zorder=2)
# gamma = Sh/Nu*2*0.01
# plt.plot(time[start:end],gamma[start:end],'r', linewidth= '1', label=r'$\gamma$',zorder=2)
plt.xlabel(r'$T_{po}$', fontsize=fontsize)
# plt.ylabel([],fontsize=14)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.legend()
plt.savefig('highPr/Pr7/Ra40000/PO1/PO1_one_period.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # Ra = 33800

# %%
from func import *

plot_NuSh = False
plot_JtNu = False
plot_JcSh = True
plot_DI = False

fontsize = 16
plt.figure(figsize=(3, 3))
# PO1, T~43->44
start=0
end = -200

T=44 # 43.74

x=[]
y=[]
x_po=[]
y_po=[]
x_eq=[]
y_eq=[]
# get dns data of PO1
if plot_JtNu:
    [_,x]=readdata("highPr/Pr7/Ra33800/check_PO_from_S1/dns/energy.asc",16)
    [_,y]=readdata("highPr/Pr7/Ra33800/check_PO_from_S1/dns/energy.asc",17)
    [_,x_po]=readdata("highPr/Pr7/Ra33800/check_PO1/PO1_dns/energy.asc",16)
    [_,y_po]=readdata("highPr/Pr7/Ra33800/check_PO1/PO1_dns/energy.asc",17)
    [_,x_eq]=readdata("highPr/Pr7/Ra33800/S1/fieldconverge.asc",15)
    [_,y_eq]=readdata("highPr/Pr7/Ra33800/S1/fieldconverge.asc",16)
    plt.xlabel(r'$J_t$', fontsize=fontsize)
    plt.ylabel(r'$Nu$', fontsize=fontsize)
    # x_eq = y_eq = Nusselt("highPr/Pr7/Ra33800/S1/tbest.nc")
elif plot_JcSh:
    [_,x]=readdata("highPr/Pr7/Ra33800/check_PO_from_S1/dns/energy.asc",21)
    [_,y]=readdata("highPr/Pr7/Ra33800/check_PO_from_S1/dns/energy.asc",22)
    [_,x_po]=readdata("highPr/Pr7/Ra33800/check_PO1/PO1_dns/energy.asc",21)
    [_,y_po]=readdata("highPr/Pr7/Ra33800/check_PO1/PO1_dns/energy.asc",22)
    [_,x_eq]=readdata("highPr/Pr7/Ra33800/S1/fieldconverge.asc",20)
    [_,y_eq]=readdata("highPr/Pr7/Ra33800/S1/fieldconverge.asc",21)
    # plt.xlabel(r'$J_c$', fontsize=fontsize)
    # plt.ylabel(r'$Sh$', fontsize=fontsize)
    # x_eq = y_eq = Nusselt("highPr/Pr7/Ra33800/S1/sbest.nc")
else:
    [_,x]=readdata("highPr/Pr7/Ra33800/check_PO_from_S1/dns/energy.asc",4)
    [_,y]=readdata("highPr/Pr7/Ra33800/check_PO_from_S1/dns/energy.asc",23)
    [_,x_po]=readdata("highPr/Pr7/Ra33800/check_PO1/PO1_dns/energy.asc",4)
    [_,y_po]=readdata("highPr/Pr7/Ra33800/check_PO1/PO1_dns/energy.asc",23)
    [_,x_eq]=readdata("highPr/Pr7/Ra33800/S1/fieldconverge.asc",3)
    [_,y_eq]=readdata("highPr/Pr7/Ra33800/S1/fieldconverge.asc",22)
    plt.xlabel(r'$D$', fontsize=fontsize)
    plt.ylabel(r'$I$', fontsize=fontsize)



# plot time history of dns of perturbed PO
# plt.plot(x[start:end],y[start:end],marker='o',markersize='1.2',color='k', linewidth= '0.3', label='Perturbed S1',alpha=0.3,zorder=1)
# plt.plot(x[start:end]/y[start:end],y[start:end],marker='o',markersize='1.2',color='k', linewidth= '0.3', label='Perturbed S1',alpha=0.3,zorder=1)

# plot single period T of PO
plt.plot(x_po[start:start+T+1],y_po[start:start+T+1],marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
# plt.plot(x_po[start:start+T+1]/y_po[start:start+T+1],y_po[start:start+T+1]/x_po[start:start+T+1],marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)

# plot eq point
# plt.scatter(x_eq[-1],y_eq[-1],marker='*',color='r',label='S1',zorder=3)
print("Nusselt =",x_eq[-1])

# plt.scatter(x_po[1],y_po[1],marker='*',color='k',zorder=3)
# plt.scatter(x_po[10],y_po[10],marker='*',color='k',zorder=3)
# plt.scatter(x_po[20],y_po[20],marker='*',color='k',zorder=3)
# plt.scatter(x_po[36],y_po[36],marker='*',color='k',zorder=3)

# plt.scatter(x_po[1],y_po[1],marker='*',color='k',zorder=3)
plt.scatter(x_po[18],y_po[18],marker='*',color='g',zorder=3)
# plt.scatter(x_po[20],y_po[20],marker='*',color='k',zorder=3)
plt.scatter(x_po[1],y_po[1],marker='*',color='g',zorder=3)

ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)

plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)

if plot_NuSh:
    plt.plot(x_po[start:start+T+1],y_po[start:start+T+1],marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
    plt.savefig('PO1_Phase_portrait_NuSh.png', dpi=300, bbox_inches='tight')
elif plot_JtNu:
    plt.savefig('PO1_Phase_portrait_JtNu.png', dpi=300, bbox_inches='tight')
elif plot_JcSh:
    # plt.xlim([2.7,2.85])
    # plt.legend()
    plt.savefig('PO1_Phase_portrait_JcSh.png', dpi=300, bbox_inches='tight')
else:
    plt.savefig('PO1_Phase_portrait_DI.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# Nusselt = 2.83818

# %%
# S1 steady solution
from func import *

########## this for upper branch of solution S1   
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('highPr/Pr7/Ra33800/check_PO1/PO1_dns/t1.nc',2)
plot_scalar(z,y,scalar,-0.4,0.4,False)
plt.savefig('PO1_t_1.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('highPr/Pr7/Ra33800/check_PO1/PO1_dns/t10.nc',2)
plot_scalar(z,y,scalar,-0.4,0.4,False)
plt.savefig('PO1_t_10.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('highPr/Pr7/Ra33800/check_PO1/PO1_dns/t20.nc',2)
plot_scalar(z,y,scalar,-0.4,0.4,False)
plt.savefig('PO1_t_21.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('highPr/Pr7/Ra33800/check_PO1/PO1_dns/t36.nc',2)
plot_scalar(z,y,scalar,-0.4,0.4,False)
plt.savefig('PO1_t_36.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()







plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('highPr/Pr7/Ra33800/check_PO1/PO1_dns/s18.nc',2)
plot_scalar(z,y,scalar,-0.37,0.37,False)
plt.savefig('PO1_c_18.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('highPr/Pr7/Ra33800/check_PO1/PO1_dns/s1.nc',2)
plot_scalar(z,y,scalar,-0.37,0.37,False)
plt.savefig('PO1_c_1.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
