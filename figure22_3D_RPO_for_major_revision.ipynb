# %% [markdown]
# ## Ra=5000: Relative periodic orbit

# %%
from func import *
[time,Nu]=readdata("Data/Equilibrium_3D_effect/Ra5000/dns_rpo/energy.asc",17)
start=0
end = -1
# T ~ 305

plt.figure(figsize=(15, 4))
plt.plot(time[start:end],Nu[start:end],'-',zorder=1)
plt.scatter(time[20],Nu[20],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[70],Nu[70],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[90],Nu[90],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[140],Nu[140],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[170],Nu[170],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[210],Nu[210],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[240],Nu[240],c='k',marker='*',s=20,zorder=2)
plt.scatter(time[290],Nu[290],c='k',marker='*',s=20,zorder=2)
plt.ylabel(r'$Nu$', fontsize=14)
plt.xlabel(r'$t$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(1.3,1.4)
plt.xlim(left=0, right=time[end])
plt.savefig("Data/Equilibrium_3D_effect/Ra5000/Figure22_3D_RPO_Nu.png", dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# Data of snapshots associated with star markers is saved to folder `"Data/Equilibrium_3D_effect/Ra5000/dns_rpo/"`
#
# The relative periodic orbit converged by Newton solver is saved to folder `"Data/Equilibrium_3D_effect/Ra5000/RPO_converged/"`

# %% [markdown]
# # Full dns from chaos to stable relative periodic orbit

# %%
from func import *
[time,Jt]=readdata("Data/Equilibrium_3D_effect/Ra5000/full_dns/energy.asc",16)
[_,Nu]=readdata("Data/Equilibrium_3D_effect/Ra5000/full_dns/energy.asc",22)
start=0
end = -1
# T_orbit ~ 305

plt.figure(figsize=(8, 3))
plt.plot(time[start:end],Nu[start:end])
plt.xlim(left=0)
plt.ylabel(r'$Nu$', fontsize=14)
plt.xlabel(r'$t$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.close()
