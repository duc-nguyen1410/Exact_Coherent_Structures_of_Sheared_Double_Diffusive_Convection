# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['mathtext.fontset'] = 'stix'  # Use STIX fonts for math symbols
plt.rcParams['text.usetex'] = True # enable LaTeX rendering

marker_size = 12
plt.figure(figsize=(8, 1.5))

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case1_meanProfiles.csv', delimiter=',')
ddc_case1_y = ddc[:, 0]
ddc_case1_mtemp = ddc[:, 1]
ddc_case1_msalt = ddc[:, 2]
plt.plot(ddc_case1_msalt+0,ddc_case1_y,color='k', linestyle = 'solid')
plt.plot(ddc_case1_mtemp+0,ddc_case1_y,color='r', linestyle = 'solid')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case1_s.csv', delimiter=',')
yang_case1_y = yang[:, 1][::-1]
yang_case1_msalt = yang[:, 0][::-1]
# plt.plot(yang_case1_msalt+0,yang_case1_y,color='g', linestyle = 'dashed')
plt.scatter(yang_case1_msalt+0,yang_case1_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1)
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case1_t.csv', delimiter=',')
yang_case1_y = yang[:, 1][::-1]
yang_case1_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case1_mtemp+0,yang_case1_y,color='g', linestyle = 'dashdot')
plt.scatter(yang_case1_mtemp+0,yang_case1_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1)

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case2_meanProfiles.csv', delimiter=',')
ddc_case2_y = ddc[:, 0]
ddc_case2_mtemp = ddc[:, 1]
ddc_case2_msalt = ddc[:, 2]
plt.plot(ddc_case2_msalt+1,ddc_case1_y,color='k', linestyle = 'solid')
plt.plot(ddc_case2_mtemp+1,ddc_case1_y,color='r', linestyle = 'solid')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case2_s.csv', delimiter=',')
yang_case2_y = yang[:, 1][::-1]
yang_case2_msalt = yang[:, 0][::-1]
# plt.plot(yang_case2_msalt+1,yang_case2_y,color='g', linestyle = 'dashed')
plt.scatter(yang_case2_msalt+1,yang_case2_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1)
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case2_t.csv', delimiter=',')
yang_case2_y = yang[:, 1][::-1]
yang_case2_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case2_mtemp+1,yang_case2_y,color='g', linestyle = 'dashdot')
plt.scatter(yang_case2_mtemp+1,yang_case2_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1)

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case3_meanProfiles.csv', delimiter=',')
ddc_case3_y = ddc[:, 0]
ddc_case3_mtemp = ddc[:, 1]
ddc_case3_msalt = ddc[:, 2]
plt.plot(ddc_case3_msalt+2,ddc_case3_y,color='k', linestyle = 'solid')
plt.plot(ddc_case3_mtemp+2,ddc_case3_y,color='r', linestyle = 'solid')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case3_s.csv', delimiter=',')
yang_case3_y = yang[:, 1][::-1]
yang_case3_msalt = yang[:, 0][::-1]
# plt.plot(yang_case3_msalt+2,yang_case3_y,color='g', linestyle = 'dashed')
plt.scatter(yang_case3_msalt+2,yang_case3_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1)
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case3_t.csv', delimiter=',')
yang_case3_y = yang[:, 1][::-1]
yang_case3_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case3_mtemp+2,yang_case3_y,color='g', linestyle = 'dashdot')
plt.scatter(yang_case3_mtemp+2,yang_case3_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1)

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case4_meanProfiles.csv', delimiter=',')
ddc_case4_y = ddc[:, 0]
ddc_case4_mtemp = ddc[:, 1]
ddc_case4_msalt = ddc[:, 2]
plt.plot(ddc_case4_msalt+3,ddc_case4_y,color='k', linestyle = 'solid',label=r'$\langle S\rangle_{h,t}$, ChFlow--DDC')
plt.plot(ddc_case4_mtemp+3,ddc_case4_y,color='r', linestyle = 'solid',label=r'$\langle T\rangle_{h,t}$, ChFlow--DDC')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case4_s.csv', delimiter=',')
yang_case4_y = yang[:, 1][::-1]
yang_case4_msalt = yang[:, 0][::-1]
# plt.plot(yang_case4_msalt+3,yang_case4_y,color='g', linestyle = 'dashed',label=r'$\overline{S}$, Yang et al. (2015)')
plt.scatter(yang_case4_msalt+3,yang_case4_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1,label=r'$\langle S\rangle_{h,t}$, Yang \textit{et al.} (2015)')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case4_t.csv', delimiter=',')
yang_case4_y = yang[:, 1][::-1]
yang_case4_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case4_mtemp+3,yang_case4_y,color='g', linestyle = 'dashdot',label=r'$\overline{T}$, Yang et al. (2015)')
plt.scatter(yang_case4_mtemp+3,yang_case4_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1,label=r'$\langle T\rangle_{h,t}$, Yang \textit{et al.} (2015)')
plt.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.5),
    ncol=2, 
)

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case5_meanProfiles.csv', delimiter=',')
ddc_case5_y = ddc[:, 0]
ddc_case5_mtemp = ddc[:, 1]
ddc_case5_msalt = ddc[:, 2]
plt.plot(ddc_case5_msalt+4,ddc_case5_y,color='k', linestyle = 'solid')
plt.plot(ddc_case5_mtemp+4,ddc_case5_y,color='r', linestyle = 'solid')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case5_s.csv', delimiter=',')
yang_case5_y = yang[:, 1][::-1]
yang_case5_msalt = yang[:, 0][::-1]
# plt.plot(yang_case5_msalt+4,yang_case5_y,color='g', linestyle = 'dashed')
plt.scatter(yang_case5_msalt+4,yang_case5_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1)
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case5_t.csv', delimiter=',')
yang_case5_y = yang[:, 1][::-1]
yang_case5_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case5_mtemp+4,yang_case5_y,color='g', linestyle = 'dashdot')
plt.scatter(yang_case5_mtemp+4,yang_case5_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1)

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case6_meanProfiles.csv', delimiter=',')
ddc_case6_y = ddc[:, 0]
ddc_case6_mtemp = ddc[:, 1]
ddc_case6_msalt = ddc[:, 2]
plt.plot(ddc_case6_msalt+5,ddc_case6_y,color='k', linestyle = 'solid')
plt.plot(ddc_case6_mtemp+5,ddc_case6_y,color='r', linestyle = 'solid')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case6_s.csv', delimiter=',')
yang_case6_y = yang[:, 1][::-1]
yang_case6_msalt = yang[:, 0][::-1]
# plt.plot(yang_case6_msalt+5,yang_case6_y,color='g', linestyle = 'dashed')
plt.scatter(yang_case6_msalt+5,yang_case6_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1)
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case6_t.csv', delimiter=',')
yang_case6_y = yang[:, 1][::-1]
yang_case6_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case6_mtemp+5,yang_case6_y,color='g', linestyle = 'dashdot')
plt.scatter(yang_case6_mtemp+5,yang_case6_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1)

ddc = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/case7_meanProfiles.csv', delimiter=',')
ddc_case7_y = ddc[:, 0]
ddc_case7_mtemp = ddc[:, 1]
ddc_case7_msalt = ddc[:, 2]
plt.plot(ddc_case7_msalt+6,ddc_case7_y,color='k', linestyle = 'solid',label=r'$\langle S\rangle_h$')
plt.plot(ddc_case7_mtemp+6,ddc_case7_y,color='r', linestyle = 'solid',label=r'$\langle T\rangle_h$')
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case7_s.csv', delimiter=',')
yang_case7_y = yang[:, 1][::-1]
yang_case7_msalt = yang[:, 0][::-1]
# plt.plot(yang_case7_msalt+6,yang_case7_y,color='g', linestyle = 'dashed')
plt.scatter(yang_case7_msalt+6,yang_case7_y,color='g',edgecolors='none',s=marker_size,alpha=0.9, zorder=1)
yang = np.loadtxt('Data/Validations/Validation_SaltFingers_Yang2015/Yang2015/case7_t.csv', delimiter=',')
yang_case7_y = yang[:, 1][::-1]
yang_case7_mtemp = yang[:, 0][::-1]
# plt.plot(yang_case7_mtemp+6,yang_case7_y,color='g', linestyle = 'dashdot')
plt.scatter(yang_case7_mtemp+6,yang_case7_y,color='g',edgecolors='none',marker='s',s=marker_size,alpha=0.9, zorder=1)

# plt.xlabel(r'$\bar{\rho}(y)$', fontsize=14)
plt.ylabel(r'$z$', fontsize=14)
plt.xticks([0, 1,2,3,4,5,6,7],['0','1','2','3','4','5','6','7'],fontsize=14)
plt.yticks([0, 0.5, 1],['0','0.5','1'],fontsize=14)
# plt.xlim(-1, 1)
# plt.ylim(-0.05, 1.05)
# plt.grid()



plt.savefig('Data/Validations/Validation_SaltFingers_Yang2015/Validations_of_Mean_Profiles_Yang2015.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
