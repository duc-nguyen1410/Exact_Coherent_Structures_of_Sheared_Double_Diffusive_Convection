# %% [markdown]
# ## Plot bifurcation diagram with stability
# - Solid line: stable
# - Dashed line: unstable (real part > $10^{-6}$)

# %%
from func import *
fontsize = 16
plt.figure(figsize=(5, 3))

print("get E1 bifurcation")
Pr, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E1_Pr_Nu.npz").values()
segments = separate_into_segments(Pr, Nu, instability)
plot_stability_bifurcation(segments,'E1','r')
plt.scatter(Pr[40],Nu[40],marker='x',color='r',zorder=3)
plt.scatter(Pr[25],Nu[25],marker='d',facecolors='none',color='r',zorder=3)

print("get E2 bifurcation")
Pr, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E2_Pr_Nu.npz").values()
segments = separate_into_segments(Pr, Nu, instability)
plot_stability_bifurcation(segments,'E2','g')
plt.scatter(Pr[32],Nu[32],marker='x',color='g',zorder=3)
plt.scatter(Pr[21],Nu[21],marker='d',facecolors='none',color='g',zorder=3)

print("get E3 bifurcation")
Pr, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E3_Pr_Nu.npz").values()
segments = separate_into_segments(Pr, Nu, instability)
plot_stability_bifurcation(segments,'E3','k')
plt.scatter(Pr[35],Nu[35],marker='x',color='k',zorder=3)
plt.scatter(Pr[18],Nu[18],marker='d',facecolors='none',color='k',zorder=3)

print("get E4 bifurcation")
Pr, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E4_Pr_Nu.npz").values()
segments = separate_into_segments(Pr, Nu, instability)
plot_stability_bifurcation(segments,'E4','tab:gray')
plt.scatter(Pr[40],Nu[40],marker='x',color='tab:gray',zorder=3)
plt.scatter(Pr[23],Nu[23],marker='d',facecolors='none',color='tab:gray',zorder=3)

print("get C12 bifurcation")
Pr, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_C12_Pr_Nu.npz").values()
segments = separate_into_segments(Pr, Nu, instability)
plot_stability_bifurcation(segments,'C12','c')

print("get C24 bifurcation")
Pr, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_C24_Pr_Nu.npz").values()
segments = separate_into_segments(Pr, Nu, instability)
plot_stability_bifurcation(segments,'C24','y')

plt.scatter([],[],marker='x',label='SN',color='k',zorder=3)
plt.scatter([],[],marker='d',facecolors='none',label='HB',color='k',zorder=3)

plt.xlabel(r'$Pr$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlim([6.9,60])
plt.xscale('linear')
plt.legend(ncol=2,frameon=False)

plt.savefig('Data/Equilibrium_parameter_effect/EQCont_PrNu.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# get E1 bifurcation
# get E2 bifurcation
# get E3 bifurcation
# get E4 bifurcation
# get C12 bifurcation
# get C24 bifurcation
