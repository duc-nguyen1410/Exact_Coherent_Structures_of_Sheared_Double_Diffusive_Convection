# %% [markdown]
# # E2-3D

# %% [markdown]
# ## Plot spanwise-averaged profiles of total temperature and salinity

# %%
from func import *

plt.figure(figsize=(10, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE2_Ly0.5pi/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE2_temp_xz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(10, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE2_Ly0.5pi/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE2_salt_xz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Plot streamwise-averaged profiles of total temperature and salinity

# %%
from func import *

plt.figure(figsize=(10, 1))
[y,z,scalar] = x_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE2_Ly0.5pi/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
plt.xlabel(r'$y$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
# plt.xticks([0,np.pi,2*np.pi], [r'0', r'$\pi$', r'$2\pi$'],fontsize=16)
# plt.yticks([-0.5, 0, 0.5],[r'$-0.5$',r'0',r'0.5'],fontsize=16)
plt.xlim(0, np.pi/2)
plt.xticks([0, np.pi/2],['0',r'$\pi/2$'], fontsize=16)
plt.ylim(-0.5, 0.5)
print(np.min(scalar),np.max(scalar))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE2_temp_yz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(10, 1))
[y,z,scalar] = x_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE2_Ly0.5pi/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
plt.xlabel(r'$y$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
# plt.xticks([0,np.pi,2*np.pi], [r'0', r'$\pi$', r'$2\pi$'],fontsize=16)
# plt.yticks([-0.5, 0, 0.5],[r'$-0.5$',r'0',r'0.5'],fontsize=16)
plt.xlim(0, np.pi/2)
plt.xticks([0, np.pi/2],['0',r'$\pi/2$'], fontsize=16)
plt.ylim(-0.5, 0.5)
print(np.min(scalar),np.max(scalar))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE2_salt_yz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# -0.22907467281175273 0.22906300645470035
# -0.3564131175527406 0.3564216238111866

# %% [markdown]
# # E4-3D

# %% [markdown]
# ## Plot spanwise-averaged profiles of total temperature and salinity

# %%
from func import *

########## this for upper branch of solution S1   
plt.figure(figsize=(10, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE4_Ly0.5pi/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
print(np.min(scalar),np.max(scalar))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE4_temp_xz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(10, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE4_Ly0.5pi/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
print(np.min(scalar),np.max(scalar))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE4_salt_xz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# -0.13993890156309452 0.13995483967712313
# -0.25707723441841973 0.2570848427854807

# %% [markdown]
# ## Plot streamwise-averaged profiles of total temperature and salinity

# %%
from func import *

########## this for upper branch of solution S1   
plt.figure(figsize=(4, 1))
[y,z,scalar] = x_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE4_Ly0.5pi/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
plt.xlabel(r'$y$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
# plt.xticks([0,np.pi,2*np.pi], [r'0', r'$\pi$', r'$2\pi$'],fontsize=16)
# plt.yticks([-0.5, 0, 0.5],[r'$-0.5$',r'0',r'0.5'],fontsize=16)
plt.xlim(0, np.pi/2)
plt.xticks([0, np.pi/2],['0',r'$\pi/2$'], fontsize=16)
plt.ylim(-0.5, 0.5)
print(np.min(scalar),np.max(scalar))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE4_temp_yz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = x_averaged_scalar('Data/Equilibrium_3D_effect/Ra20000/3DE4_Ly0.5pi/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
plt.xlabel(r'$y$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
# plt.xticks([0,np.pi,2*np.pi], [r'0', r'$\pi$', r'$2\pi$'],fontsize=16)
# plt.yticks([-0.5, 0, 0.5],[r'$-0.5$',r'0',r'0.5'],fontsize=16)
plt.xlim(0, np.pi/2)
plt.xticks([0, np.pi/2],['0',r'$\pi/2$'], fontsize=16)
plt.ylim(-0.5, 0.5)
print(np.min(scalar),np.max(scalar))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/3DE4_salt_yz.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# -0.12110590836738824 0.12110314635070793
# -0.2651774442675493 0.26517228806470716

# %% [markdown]
# ## Plot horizontally-averaged profiles

# %%
from func import *

plt.figure(figsize=(3, 2.3))
### mean profiles of EQ3D
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/3DE2_Ly0.5pi/tbest.nc')
plt.plot(xz_ave_T-y,y,color='r',  linestyle = 'solid',label=r'$\langle T\rangle_h$, E2--3D')
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/3DE2_Ly0.5pi/sbest.nc')
plt.plot(xz_ave_S-y,y,color='tab:blue',linestyle = 'solid',label=r'$\langle S\rangle_h$, E2--3D')
### mean profiles of EQ2D
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/2DE2_Ly0.5pi/tbest.nc')
plt.plot(xz_ave_T-y,y,color='r',  linestyle = 'dashed',label=r'$\langle T\rangle_h$, E2')
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/2DE2_Ly0.5pi/sbest.nc')
plt.plot(xz_ave_S-y,y,color='tab:blue',linestyle = 'dashed',label=r'$\langle S\rangle_h$, E2')

# plt.xlabel(r'$\overline{T},\overline{S}$', fontsize=14)
plt.ylabel(r'$z$', fontsize=16)
plt.xticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.yticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.xlim(-0.5, 0.5)
plt.ylim(-0.5, 0.5)
# plt.gca().set_aspect('equal')
# plt.grid()
plt.legend(fontsize=8)
# plt.legend(ncol=2,loc='lower center', bbox_to_anchor=(0.2, 1))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/meanProfiles_E2.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
from func import *

plt.figure(figsize=(3, 2.3))
### mean profiles of EQ3D
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/3DE4_Ly0.5pi/tbest.nc')
plt.plot(xz_ave_T-y,y,color='r',  linestyle = 'solid',label=r'$\langle T\rangle_h$, E4-3D')
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/3DE4_Ly0.5pi/sbest.nc')
plt.plot(xz_ave_S-y,y,color='tab:blue',linestyle = 'solid',label=r'$\langle S\rangle_h$, E4-3D')
### mean profiles of EQ2D
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/2DE4_Ly0.5pi/tbest.nc')
plt.plot(xz_ave_T-y,y,color='r',  linestyle = 'dashed',label=r'$\langle T\rangle_h$, E4')
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium_3D_effect/Ra20000/2DE4_Ly0.5pi/sbest.nc')
plt.plot(xz_ave_S-y,y,color='tab:blue',linestyle = 'dashed',label=r'$\langle S\rangle_h$, E4')

# plt.xlabel(r'$\overline{T},\overline{S}$', fontsize=14)
plt.ylabel(r'$z$', fontsize=16)
plt.xticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.yticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.xlim(-0.5, 0.5)
plt.ylim(-0.5, 0.5)
# plt.gca().set_aspect('equal')
# plt.grid()
plt.legend(fontsize=8)
# plt.legend(ncol=2,loc='lower center', bbox_to_anchor=(0.2, 1))
plt.savefig('Data/Equilibrium_3D_effect/Ra20000/meanProfiles_E4.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
