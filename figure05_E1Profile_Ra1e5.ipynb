# %% [markdown]
# # Plot fluctuations of fields of E1 at Ra=1e5 to represent a tilted roll state

# %%
# S1 steady solution
from func import *

plt.figure(figsize=(5, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E1/tbest.nc',2)
plot_scalar(z,y,scalar,np.min(scalar),np.max(scalar),True)
plt.savefig('Data/Equilibrium/Ra1e5/E1/temp_fluc.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(5, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E1/sbest.nc',2)
plot_scalar(z,y,scalar,np.min(scalar),np.max(scalar),True)
plt.savefig('Data/Equilibrium/Ra1e5/E1/salt_fluc.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(5, 1))
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E1/ubest.nc',2)
plot_scalar(x,y,vec_x,np.min(vec_x),np.max(vec_x),True)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E1/u_fluc.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(5, 1))
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E1/ubest.nc',2)
plot_scalar(x,y,vec_y,np.min(vec_y),np.max(vec_y),True)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E1/w_fluc.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
