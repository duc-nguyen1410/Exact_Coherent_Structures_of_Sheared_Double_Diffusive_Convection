# %% [markdown]
# ## Plot bifurcation diagram with stability
# - Solid line: stable
# - Dashed line: unstable (real part > $10^{-6}$)

# %%
from func import *

fontsize = 16
plt.figure(figsize=(6, 3))

print("get E1 bifurcation")
Ly, Nu, instability = np.load("Data/Equilibrium_3D_effect/continuation_E1_Ly_Sh.npz").values()
segments = separate_into_segments(Ly, Nu, instability)
plot_stability_bifurcation(segments,'E1','r')

print("get E2 bifurcation")
Ly, Nu, instability = np.load("Data/Equilibrium_3D_effect/continuation_E2_Ly_Sh.npz").values()
segments = separate_into_segments(Ly, Nu, instability)
plot_stability_bifurcation(segments,'E2','g')

print("get E3 bifurcation")
Ly, Nu, instability = np.load("Data/Equilibrium_3D_effect/continuation_E3_Ly_Sh.npz").values()
segments = separate_into_segments(Ly, Nu, instability)
plot_stability_bifurcation(segments,'E3','k')

print("get E4 bifurcation")
Ly, Nu, instability = np.load("Data/Equilibrium_3D_effect/continuation_E4_Ly_Sh.npz").values()
segments = separate_into_segments(Ly, Nu, instability)
plot_stability_bifurcation(segments,'E4','tab:gray')

print("get 3DE2 bifurcation")
Ly, Nu, instability = np.load("Data/Equilibrium_3D_effect/continuation_E2-3D_Ly_Sh.npz").values()
segments = separate_into_segments(Ly, Nu, instability)
plot_stability_bifurcation(segments,'E2--3D','tab:blue')

print("get 3DE4 bifurcation")
Ly, Nu, instability = np.load("Data/Equilibrium_3D_effect/continuation_E4-3D_Ly_Sh.npz").values()
segments = separate_into_segments(Ly, Nu, instability)
plot_stability_bifurcation(segments,'E4--3D','tab:orange')


plt.xlabel(r'$L_y$', fontsize=fontsize)
plt.ylabel(r'$Sh$', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
# plt.ylim([1,6])
plt.xlim([0,np.pi])
plt.xticks([0,np.pi/4,np.pi/2,3*np.pi/4,np.pi],[r'$0$',r'$\pi/4$',r'$\pi/2$',r'$3\pi/4$',r'$\pi$'])
# plt.xscale('linear')
plt.legend(frameon=False)


plt.ylim([1,6])
# plt.legend(
#     loc='right', 
#     bbox_to_anchor=(1.3, 0.5),
#     ncol=1, 
# )
plt.savefig('Data/Equilibrium_3D_effect/3Deffects_LySh.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
