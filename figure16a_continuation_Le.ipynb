# %% [markdown]
# ## Plot bifurcation diagram with stability
# - Solid line: stable
# - Dashed line: unstable (real part > $10^{-6}$)

# %%
from func import *

fontsize = 16
plt.figure(figsize=(5, 3))

print("get E1 bifurcation")
tau, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E1_tau_Nu.npz").values()
segments = separate_into_segments(tau, Nu, instability)
plot_stability_bifurcation(segments,'E1','r')
plt.scatter(tau[30],Nu[30],marker='x',color='r',zorder=3)
plt.scatter(tau[19],Nu[19],marker='d',facecolors='none',color='r',zorder=3)

print("get E2 bifurcation")
tau, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E2_tau_Nu.npz").values()
segments = separate_into_segments(tau, Nu, instability)
plot_stability_bifurcation(segments,'E2','g')
plt.scatter(tau[30],Nu[30],marker='x',color='g',zorder=3)
plt.scatter(tau[20],Nu[20],marker='d',facecolors='none',color='g',zorder=3)

print("get E3 bifurcation")
tau, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E3_tau_Nu.npz").values()
segments = separate_into_segments(tau, Nu, instability)
plot_stability_bifurcation(segments,'E3','k')
plt.scatter(tau[32],Nu[32],marker='x',color='k',zorder=3)
plt.scatter(tau[25],Nu[25],marker='d',facecolors='none',color='k',zorder=3)

print("get E4 bifurcation")
tau, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_E4_tau_Nu.npz").values()
segments = separate_into_segments(tau, Nu, instability)
plot_stability_bifurcation(segments,'E4','tab:gray')
plt.scatter(tau[40],Nu[40],marker='x',color='tab:gray',zorder=3)
plt.scatter(tau[32],Nu[32],marker='d',facecolors='none',color='tab:gray',zorder=3)

print("get C12 bifurcation")
tau, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_C12_tau_Nu.npz").values()
segments = separate_into_segments(tau, Nu, instability)
plot_stability_bifurcation(segments,'C12','c')

print("get C24 bifurcation")
tau, Nu, instability = np.load("Data/Equilibrium_parameter_effect/continuation_C24_tau_Nu.npz").values()
segments = separate_into_segments(tau, Nu, instability)
plot_stability_bifurcation(segments,'C24','y')

plt.xlabel(r'$\tau$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
# plt.xlim([0.01,0.2])
# plt.ylim([0.95,2.05])
# plt.legend(frameon=False)
plt.savefig('Data/Equilibrium_parameter_effect/EQCont_tauNu.png', dpi=300, bbox_inches='tight')

plt.show()
plt.close()
# Out:
# get E1 bifurcation
# get E2 bifurcation
# get E3 bifurcation
# get E4 bifurcation
# get C12 bifurcation
# get C24 bifurcation
