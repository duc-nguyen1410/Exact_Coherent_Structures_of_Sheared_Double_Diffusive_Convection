# %% [markdown]
# # Bifurcation diagram of E1+C12

# %%
from func import *
fontsize = 16

plt.figure(figsize=(5, 2))
################# get continuation for E1 steady solution
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_E1_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'E1','r')
    
################# get continuation for C12 steady solution
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_C12_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'C12','c')

# plot snapshots
def read_mu(dir):
    with open(dir, 'r') as file:
        exact_mu = float(file.read().strip())
        return exact_mu
Ra=read_mu('Data/Equilibrium/E1C12_Ra_continuation/point_i/mu.asc')
Nu=Nusselt("Data/Equilibrium/E1C12_Ra_continuation/point_i/tbest.nc")
plt.scatter(Ra,Nu,marker='*',color='k',zorder=3)

Ra=read_mu('Data/Equilibrium/E1C12_Ra_continuation/point_ii/mu.asc')
Nu=Nusselt("Data/Equilibrium/E1C12_Ra_continuation/point_ii/tbest.nc")
plt.scatter(Ra,Nu,marker='*',color='k',zorder=3)

Ra=read_mu('Data/Equilibrium/E1C12_Ra_continuation/point_iii/mu.asc')
Nu=Nusselt("Data/Equilibrium/E1C12_Ra_continuation/point_iii/tbest.nc")
plt.scatter(Ra,Nu,marker='*',color='k',zorder=3)

Ra=read_mu('Data/Equilibrium/E1C12_Ra_continuation/point_iv/mu.asc')
Nu=Nusselt("Data/Equilibrium/E1C12_Ra_continuation/point_iv/tbest.nc")
plt.scatter(Ra,Nu,marker='*',color='k',zorder=3)

Ra=read_mu('Data/Equilibrium/E1C12_Ra_continuation/point_v/mu.asc')
Nu=Nusselt("Data/Equilibrium/E1C12_Ra_continuation/point_v/tbest.nc")
plt.scatter(Ra,Nu,marker='*',color='k',zorder=3)


plt.xlabel(r'$Ra$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlim([1e4, 1e6])
plt.xscale('log')
plt.legend(frameon=False)
plt.savefig('Data/Equilibrium/bifurcation_C12.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Distribution of total temperature at 5 points

# %%
# E1 steady solution
from func import *

# upper branch E1
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_i/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_i/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_i/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_ii/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_ii/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_ii/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# C12
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_iii/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_iii/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_iii/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_iv/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_iv/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_iv/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_v/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_v/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_v/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Distribution of total salinity at 5 points

# %%
# E1 steady solution
from func import *

# upper branch E1
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_i/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_i/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_i/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_ii/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_ii/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_ii/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# C12
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_iii/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_iii/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_iii/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_iv/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_iv/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_iv/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/E1C12_Ra_continuation/point_v/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/E1C12_Ra_continuation/point_v/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/E1C12_Ra_continuation/point_v/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
