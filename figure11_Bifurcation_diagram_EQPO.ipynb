# %% [markdown]
# # Plot bifurcation diagram with stability
# - Solid line: stable
# - Dashed line: unstable (real part > $10^{-6}$)

# %% [markdown]
# ## Nu as function of Ra

# %%
from func import *
fontsize = 16
plt.figure(figsize=(5, 3))
############################ Equilibrium #############################
################### get continuation for base solution

print("get base state's bifurcation")
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_base_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,r'Base','b')

############## get continuation for E1 steady solution
print("get E1's bifurcation")
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_E1_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'E1','r')
RaSN, NuSN = np.load("Data/Equilibrium/saddlenode_E1_Ra_Nu.npz").values()
plt.scatter(RaSN,NuSN,marker='x',color='r',zorder=3)
RaHB, NuHB = np.load("Data/Equilibrium/hopf_E1_Ra_Nu.npz").values()
plt.scatter(RaHB,NuHB,marker='d',facecolors='none',color='r',zorder=3)

############### get continuation for E2 steady solution
print("get E2's bifurcation")
Ra, Nu, instability = np.load("Data/Equilibrium/continuation_E2_Ra_Nu.npz").values()
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'E2','g')
RaSN, NuSN = np.load("Data/Equilibrium/saddlenode_E2_Ra_Nu.npz").values()
plt.scatter(RaSN,NuSN,marker='x',color='g',zorder=3)
RaHB, NuHB = np.load("Data/Equilibrium/hopf_E2_Ra_Nu.npz").values()
plt.scatter(RaHB,NuHB,marker='d',facecolors='none',color='g',zorder=3)


################# get continuation for E3 steady solution
print("get E3's bifurcation")
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_E3_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'E3','k')
RaSN, NuSN = np.load("Data/Equilibrium/saddlenode_E3_Ra_Nu.npz").values()
plt.scatter(RaSN,NuSN,marker='x',color='k',label='SN',zorder=3)
RaHB, NuHB = np.load("Data/Equilibrium/hopf_E3_Ra_Nu.npz").values()
plt.scatter(RaHB,NuHB,marker='d',facecolors='none',color='k',label='HB',zorder=3)

################# get continuation for C12 steady solution
print("get C12 bifurcation")
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_C12_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'C12','c')
    

############# get continuation for C24 steady solution
print("get C24 bifurcation")
Ra, Nu, instability = (np.load("Data/Equilibrium/continuation_C24_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,Nu,instability)
plot_stability_bifurcation(segments,'C24','y')

############################ Equilibrium #############################

############################ Periodic orbits #############################
# get continuation for PO1
print("get PO1 bifurcation")
Ra, minNu, maxNu, instability = (np.load("Data/PeriodicOrbits/continuation_PO1_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,minNu,instability)
plot_stability_bifurcation(segments,'PO1','tab:brown',"dashdot")
segments = separate_into_segments(Ra,maxNu,instability)
plot_stability_bifurcation(segments,None,'tab:brown',"dashdot")

# get continuation for PO2
print("get PO2 bifurcation")
Ra, minNu, maxNu, instability = (np.load("Data/PeriodicOrbits/continuation_PO2_Ra_Nu.npz").values())
segments = separate_into_segments(Ra,minNu,instability)
plot_stability_bifurcation(segments,'PO2','m',"dashdot")
segments = separate_into_segments(Ra,maxNu,instability)
plot_stability_bifurcation(segments,None,'m',"dashdot")

############################ Periodic orbits #############################


plt.xlabel(r'$Ra$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.xlim([5000, 100000])

plt.yticks(fontsize=fontsize)
plt.xscale('linear')
# plt.legend()

plt.savefig('Data/PeriodicOrbits/bifurcation_diagram_RaNu.png', dpi=300, bbox_inches='tight')
    
plt.show()
plt.close()
# Out:
# get base state's bifurcation
# get E1's bifurcation
# get E2's bifurcation
# get E3's bifurcation
# get C12 bifurcation
# get C24 bifurcation
# get PO1 bifurcation
# get PO2 bifurcation

# %% [markdown]
# ## Sh as function of Ra

# %%
from func import *
fontsize = 16
plt.figure(figsize=(5, 3))
############################ Equilibrium #############################
################### get continuation for base solution
print("get base state's bifurcation")
Ra, Sh, instability = (np.load("Data/Equilibrium/continuation_base_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,Sh,instability)
plot_stability_bifurcation(segments,r'Base','b')

############## get continuation for E1 steady solution
print("get E1's bifurcation")
Ra, Sh, instability = (np.load("Data/Equilibrium/continuation_E1_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,Sh,instability)
plot_stability_bifurcation(segments,'E1','r')
RaSN, ShSN = np.load("Data/Equilibrium/saddlenode_E1_Ra_Sh.npz").values()
plt.scatter(RaSN,ShSN,marker='x',color='r',zorder=3)
RaHB, ShHB = np.load("Data/Equilibrium/hopf_E1_Ra_Sh.npz").values()
plt.scatter(RaHB,ShHB,marker='d',facecolors='none',color='r',zorder=3)

############### get continuation for E2 steady solution
print("get E2's bifurcation")
Ra, Sh, instability = np.load("Data/Equilibrium/continuation_E2_Ra_Sh.npz").values()
segments = separate_into_segments(Ra,Sh,instability)
plot_stability_bifurcation(segments,'E2','g')
RaSN, ShSN = np.load("Data/Equilibrium/saddlenode_E2_Ra_Sh.npz").values()
plt.scatter(RaSN,ShSN,marker='x',color='g',zorder=3)
RaHB, ShHB = np.load("Data/Equilibrium/hopf_E2_Ra_Sh.npz").values()
plt.scatter(RaHB,ShHB,marker='d',facecolors='none',color='g',zorder=3)


################# get continuation for E3 steady solution
print("get E3's bifurcation")
Ra, Sh, instability = (np.load("Data/Equilibrium/continuation_E3_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,Sh,instability)
plot_stability_bifurcation(segments,'E3','k')
RaSN, ShSN = np.load("Data/Equilibrium/saddlenode_E3_Ra_Sh.npz").values()
plt.scatter(RaSN,ShSN,marker='x',color='k',label='SN',zorder=3)
RaHB, ShHB = np.load("Data/Equilibrium/hopf_E3_Ra_Sh.npz").values()
plt.scatter(RaHB,ShHB,marker='d',facecolors='none',color='k',label='HB',zorder=3)

################# get continuation for C12 steady solution
print("get C12 bifurcation")
Ra, Sh, instability = (np.load("Data/Equilibrium/continuation_C12_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,Sh,instability)
plot_stability_bifurcation(segments,'C12','c')
    

############# get continuation for C24 steady solution
print("get C24 bifurcation")
Ra, Sh, instability = (np.load("Data/Equilibrium/continuation_C24_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,Sh,instability)
plot_stability_bifurcation(segments,'C24','y')

############################ Equilibrium #############################

############################ Periodic orbits #############################
# get continuation for PO1
print("get PO1 bifurcation")
Ra, minSh, maxSh, instability = (np.load("Data/PeriodicOrbits/continuation_PO1_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,minSh,instability)
plot_stability_bifurcation(segments,'PO1','tab:brown',"dashdot")
segments = separate_into_segments(Ra,maxSh,instability)
plot_stability_bifurcation(segments,None,'tab:brown',"dashdot")

# get continuation for PO2
print("get PO2 bifurcation")
Ra, minSh, maxSh, instability = (np.load("Data/PeriodicOrbits/continuation_PO2_Ra_Sh.npz").values())
segments = separate_into_segments(Ra,minSh,instability)
plot_stability_bifurcation(segments,'PO2','m',"dashdot")
segments = separate_into_segments(Ra,maxSh,instability)
plot_stability_bifurcation(segments,None,'m',"dashdot")

############################ Periodic orbits #############################



plt.xlabel(r'$Ra$', fontsize=fontsize)
plt.ylabel(r'$Sh$', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.xlim([5000, 100000])
plt.yticks([-5,0,5,10],fontsize=fontsize)
plt.xscale('linear')
plt.legend(
        loc='right', 
        bbox_to_anchor=(1.3, 0.5),
        ncol=1, 
    )

plt.savefig('Data/PeriodicOrbits/bifurcation_diagram_RaSh.png', dpi=300, bbox_inches='tight')
    
plt.show()
plt.close()
# Out:
# get base state's bifurcation
# get E1's bifurcation
# get E2's bifurcation
# get E3's bifurcation
# get C12 bifurcation
# get C24 bifurcation
# get PO1 bifurcation
# get PO2 bifurcation
