# %% [markdown]
# # Eigen near Hopf bifurcation point of E1

# %% [markdown]
# ## Evolution of first leading eigenvalue across Hopf bifurcation point

# %%
### plot transition of leading eigenvalue along Hopf bifurcation of S1
from func import *
import re

Ra, ReEigen, ImEigen = np.load("Data/Equilibrium/leading_eigenval_E1_near_Hopf_bifurcation_point.npz", allow_pickle=True).values()


plt.figure(figsize=(3,2))
plt.plot(Ra,ReEigen,'kx',label=r'$Re(\lambda_{1,2})$')
plt.plot([Ra.min(),Ra.max()],[0,0],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.scatter(Ra[9], ReEigen[9], marker='s', color = 'b', facecolors='none',s=50,zorder=2)
plt.scatter(Ra[12], ReEigen[12], marker='s', color = 'b', facecolors='none',s=50,zorder=2)
plt.scatter(Ra[13], ReEigen[13], marker='s', color = 'b', facecolors='none',s=50,zorder=2)
plt.scatter(Ra[17], ReEigen[17], marker='s', color = 'b', facecolors='none',s=50,zorder=2)
plt.scatter(Ra[27], ReEigen[27], marker='s', color = 'b', facecolors='none',s=50,zorder=2)
plt.xlabel(r'$Ra$',fontsize=14)
plt.ylabel(r'$\max[\mu]$',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.yticks([-0.01,0,0.01],['-0.01','0','0.01'],fontsize=14)
plt.xlim([20000,90000])
# plt.ylim([-0.015,0.015])
# plt.legend()
plt.savefig('Data/Equilibrium/E1_eigen_near_Hopf.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Distribution of spectral eigenvalues at a few points

# %%
from func import *

plt.figure(figsize=(3, 2))

[real,imag] = load_eigenvals('Data/Equilibrium/E1_Ra_continuation/downward/search-7/Lambda.asc','Data/Equilibrium/E1_Ra_continuation/downward/search-7/Residu.asc',1e-6)
plot_eigenvals(real[:22],imag[:22],False)
plt.scatter(real[:2], imag[:2], marker='o', color = 'r', facecolors='none',s=50)
plt.xlim(-0.02,0.01)
plt.ylim(-0.2,0.2)
plt.plot([-0.02,0.01],[0,0],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.plot([0,0],[-0.2,0.2],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.savefig('Data/Equilibrium/E1_Ra_continuation/E1_eigen_Ra25434.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

[real,imag] = load_eigenvals('Data/Equilibrium/E1_Ra_continuation/downward/search-4/Lambda.asc','Data/Equilibrium/E1_Ra_continuation/downward/search-4/Residu.asc',1e-6)
plt.figure(figsize=(3, 2))
plot_eigenvals(real[:22],imag[:22],False)
plt.scatter(real[:2], imag[:2], marker='o', color = 'r', facecolors='none',s=50)
plt.xlim(-0.02,0.01)
plt.ylim(-0.2,0.2)
plt.plot([-0.02,0.01],[0,0],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.plot([0,0],[-0.2,0.2],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.savefig('Data/Equilibrium/E1_Ra_continuation/E1_eigen_Ra33800.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

[real,imag] = load_eigenvals('Data/Equilibrium/E1_Ra_continuation/downward/search-3/Lambda.asc','Data/Equilibrium/E1_Ra_continuation/downward/search-3/Residu.asc',1e-6)
plt.figure(figsize=(3, 2))
plot_eigenvals(real[:22],imag[:22],False)
plt.scatter(real[:2], imag[:2], marker='o', color = 'r', facecolors='none',s=50)
plt.xlim(-0.02,0.01)
plt.ylim(-0.2,0.2)
plt.plot([-0.02,0.01],[0,0],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.plot([0,0],[-0.2,0.2],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.savefig('Data/Equilibrium/E1_Ra_continuation/E1_eigen_Ra36595.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

[real,imag] = load_eigenvals('Data/Equilibrium/E1_Ra_continuation/downward/initial-1/Lambda.asc','Data/Equilibrium/E1_Ra_continuation/downward/initial-1/Residu.asc',1e-6)
plt.figure(figsize=(3, 2))
plot_eigenvals(real[:22],imag[:22],False)
plt.scatter(real[:2], imag[:2], marker='o', color = 'r', facecolors='none',s=50)
plt.xlim(-0.02,0.04)
plt.ylim(-0.2,0.2)
plt.plot([-0.02,0.04],[0,0],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.plot([0,0],[-0.2,0.2],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.savefig('Data/Equilibrium/E1_Ra_continuation/E1_eigen_Ra50000.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

[real,imag] = load_eigenvals('Data/Equilibrium/E1_Ra_continuation/upward/search-8/Lambda.asc','Data/Equilibrium/E1_Ra_continuation/upward/search-8/Residu.asc',1e-6)
plt.figure(figsize=(3, 2))
plot_eigenvals(real[:22],imag[:22],False)
plt.scatter(real[:1], imag[:1], marker='o', color = 'r', facecolors='none',s=50)
plt.xlim(-0.02,0.1)
plt.ylim(-0.2,0.2)
plt.plot([-0.02,0.1],[0,0],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.plot([0,0],[-0.2,0.2],alpha=0.2,color='k',linewidth=1,zorder=1)
plt.savefig('Data/Equilibrium/E1_Ra_continuation/E1_eigen_Ra79080.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
