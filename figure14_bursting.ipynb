# %% [markdown]
# # Plot figure

# %%
from func import *
[time_31200,Nu_31200]=readdata("Data/DNS/heteroclinic_bursting/Ra31200/energy.asc",17)
[time_32000,Nu_32000]=readdata("Data/DNS/heteroclinic_bursting/Ra32000/energy.asc",17)
[time_33000,Nu_33000]=readdata("Data/DNS/heteroclinic_bursting/Ra33000/energy.asc",17)
[time_33800,Nu_33800]=readdata("Data/DNS/heteroclinic_bursting/Ra33800/energy.asc",17)

start=0
end = 10000

plt.figure(figsize=(6, 3))
plt.plot(time_31200[start:end],Nu_31200[start:end],label=r'$Ra=31200$',linestyle='solid')
plt.plot(time_32000[start:end],Nu_32000[start:end],label=r'$Ra=32000$',linestyle='dotted')
plt.plot(time_33000[start:end],Nu_33000[start:end],label=r'$Ra=33000$',linestyle='dashed')
plt.plot(time_33800[start:end],Nu_33800[start:end],label=r'$Ra=33800$',linestyle='dashdot')
plt.ylabel(r'$Nu$', fontsize=14)
plt.xlabel(r'$t$', fontsize=14)
plt.ylim([0.5,2.5])
plt.xticks(fontsize=14)
plt.yticks([0.5,1,1.5,2,2.5],fontsize=14)
# plt.legend(
#     ncol=2, 
#     fontsize=10,
#     frameon=False)
# plt.legend(loc='upper center', 
#     bbox_to_anchor=(0.5, 1.2),
#     ncol=2, 
#     fontsize=10,
#     frameon=False)
plt.savefig('Data/DNS/heteroclinic_bursting/DNS.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

start=0
end = 400

plt.figure(figsize=(3, 3))
plt.plot(time_31200[start:end],Nu_31200[start:end],label=r'$Ra=31200$',linestyle='solid')
plt.plot(time_32000[start:end],Nu_32000[start:end],label=r'$Ra=32000$',linestyle='dotted')
plt.plot(time_33000[start:end],Nu_33000[start:end],label=r'$Ra=33000$',linestyle='dashed')
plt.plot(time_33800[start:end],Nu_33800[start:end],label=r'$Ra=33800$',linestyle='dashdot')
plt.ylabel(r'$Nu$', fontsize=14)
plt.xlabel(r'$t$', fontsize=14)

plt.xticks(fontsize=14)
plt.yticks([0.5,1,1.5,2,2.5],fontsize=14)
plt.ylim([0.5,2.5])
plt.legend(
    ncol=1, 
    fontsize=10,
    frameon=False)
# plt.legend(loc='upper center', 
#     bbox_to_anchor=(0.5, 1.2),
#     ncol=4, 
#     fontsize=12,
#     frameon=False)
plt.savefig('Data/DNS/heteroclinic_bursting/DNS_zoomin.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
