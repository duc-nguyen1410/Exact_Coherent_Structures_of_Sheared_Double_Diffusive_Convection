# %% [markdown]
# # E1 steady solution

# %%
# E1 steady solution
from func import *

########## this for upper branch of solution E1   
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E1/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E1/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E1/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E1/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E1/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E1/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # E2 steady solution

# %%
# E2 steady solution
from func import *

########## this for upper branch of solution E2   
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E2/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E2/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E2/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E2/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E2/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E2/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # E3 steady solution

# %%
from func import *

########## this for upper branch of solution E3   
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E3/tbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E3/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E3/temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Equilibrium/Ra1e5/E3/sbest.nc',2)
plot_scalar(z,y,scalar-y,-0.5,0.5,False)
[y,x,vec_x,vec_y,vec_z] = z_averaged_vec('Data/Equilibrium/Ra1e5/E3/ubest.nc',2)
plot_streamline(x,y,vec_x,vec_y)
plt.savefig('Data/Equilibrium/Ra1e5/E3/salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # Mean profiles

# %%
from func import *

plt.figure(figsize=(1.7, 1.7))
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium/Ra1e5/E1/tbest.nc')
plt.plot(xz_ave_T-y,y,color='r', linestyle = 'solid')
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium/Ra1e5/E2/tbest.nc')
plt.plot(xz_ave_T-y,y,color='g', linestyle = 'solid')
[y,xz_ave_T] = xz_averaged_salar('Data/Equilibrium/Ra1e5/E3/tbest.nc')
plt.plot(xz_ave_T-y,y,color='k', linestyle = 'solid',label=r'$\bar{T}(y)$')
plt.xlabel(r'$\langle T \rangle_h$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
plt.xticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.yticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.gca().set_aspect('equal')
plt.grid()
plt.savefig('Data/Equilibrium/Ra1e5/MeanProfiles_E1E2E3_temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(1.7, 1.7))
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium/Ra1e5/E1/sbest.nc')
plt.plot(xz_ave_S-y,y,color='r', linestyle = 'solid',label='E1')
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium/Ra1e5/E2/sbest.nc')
plt.plot(xz_ave_S-y,y,color='g', linestyle = 'solid',label='E2')
[y,xz_ave_S] = xz_averaged_salar('Data/Equilibrium/Ra1e5/E3/sbest.nc')
plt.plot(xz_ave_S-y,y,color='k', linestyle = 'solid',label='E3')
plt.xlabel(r'$\langle S \rangle_h$', fontsize=16)
# plt.ylabel(r'$z$', fontsize=16)
plt.xticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.yticks([-0.5, 0, 0.5],[],fontsize=16)
# plt.yticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.gca().set_aspect('equal')
plt.grid()
plt.legend(fontsize=8)
plt.savefig('Data/Equilibrium/Ra1e5/MeanProfiles_E1E2E3_salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
