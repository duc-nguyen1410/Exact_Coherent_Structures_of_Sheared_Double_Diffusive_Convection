# %% [markdown]
# # Plot phase portrait (Jt, Nu) of DNS at $Ra=4\times 10^4$ visiting all ECS

# %%
from func import *
plot_JtNu = True
plot_JcSh = False
plot_NuSh = False

if plot_JtNu:
    x_idx = 15
    y_idx = 16
elif plot_JcSh:
    x_idx = 20
    y_idx = 21
elif plot_NuSh:
    x_idx = 16
    y_idx = 21


plt.figure(figsize=(5, 3))
start=0
[_,Jt]=readdata("Data/Ra40000/dns/energy.asc",x_idx+1)
[_,Nu]=readdata("Data/Ra40000/dns/energy.asc",y_idx+1)
plt.plot(Jt[start:],Nu[start:], label='DNS',color='k',alpha=0.3,linewidth=1)

[_,Jt]=readdata("Data/Ra40000/PO1/energy.asc",x_idx+1)
[_,Nu]=readdata("Data/Ra40000/PO1/energy.asc",y_idx+1)
plt.plot(Jt,Nu,marker='o',markersize='1.5',color='tab:brown', linewidth= '0.8', label='PO1',alpha=1,zorder=2)

[_,Jt]=readdata("Data/Ra40000/PO2/energy.asc",x_idx+1)
[_,Nu]=readdata("Data/Ra40000/PO2/energy.asc",y_idx+1)
plt.plot(Jt,Nu,marker='o',markersize='1.5',color='m', linewidth= '0.8', label='PO2',alpha=1,zorder=2)

[_,Jt]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='E1',marker='o',color='r',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E1_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E1_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='C12',marker='o',facecolors='none',color='r',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E2_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E2_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='E2$_{up}$',marker='s',color='g',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E2_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E2_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='E2$_{low}$',marker='s',facecolors='none',color='g',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E3_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E3_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E3$_{up}$',marker='v',color='k',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E3_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E3_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E3$_{low}$',marker='v',facecolors='none',color='k',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E4_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E4_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E4$_{up}$',marker='D',color='tab:orange',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E4_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E4_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E4$_{low}$',marker='D',facecolors='none',color='tab:orange',zorder=2)

plt.scatter(1,1, label='Base',marker='.',color='b',zorder=2)



plt.xlabel(r'$J_T$', fontsize=14)
plt.ylabel(r'$Nu$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

if plot_JtNu:
    xlims = plt.xlim()
    ylims = plt.ylim()
    minlim = min(xlims[0], ylims[0])
    maxlim = max(xlims[1], ylims[1])
    plt.plot([minlim, maxlim], [minlim, maxlim], '--', color='tab:blue', label=r'$Nu = J_T$', zorder=1)
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.xlabel(r'$J_T$', fontsize=14)
    plt.ylabel(r'$Nu$', fontsize=14)
    plt.savefig('Data/Ra40000/phase_portrait_JtNu.png', dpi=300, bbox_inches='tight')
elif plot_JcSh:
    plt.xlabel(r'$J_C$', fontsize=14)
    plt.ylabel(r'$Sh$', fontsize=14)
    plt.savefig('Data/Ra40000/phase_portrait_Jcsh.png', dpi=300, bbox_inches='tight')
elif plot_NuSh:
    plt.xlabel(r'$Nu$', fontsize=14)
    plt.ylabel(r'$Sh$', fontsize=14)
    # plt.legend()
    plt.legend(
        loc='right', 
        bbox_to_anchor=(1.3, 0.5),
        ncol=1, 
        frameon=False
    )
    plt.savefig('Data/Ra40000/phase_portrait_NuSh.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # Plot phase portrait (Nu, Sh) of DNS at $Ra=4\times 10^4$ visiting all ECS

# %%
from func import *
plot_JtNu = False
plot_JcSh = False
plot_NuSh = True

if plot_JtNu:
    x_idx = 15
    y_idx = 16
elif plot_JcSh:
    x_idx = 20
    y_idx = 21
elif plot_NuSh:
    x_idx = 16
    y_idx = 21


plt.figure(figsize=(5, 3))
start=0
[_,Jt]=readdata("Data/Ra40000/dns/energy.asc",x_idx+1)
[_,Nu]=readdata("Data/Ra40000/dns/energy.asc",y_idx+1)
plt.plot(Jt[start:],Nu[start:], label='DNS',color='k',alpha=0.3,linewidth=1)

[_,Jt]=readdata("Data/Ra40000/PO1/energy.asc",x_idx+1)
[_,Nu]=readdata("Data/Ra40000/PO1/energy.asc",y_idx+1)
plt.plot(Jt,Nu,marker='o',markersize='1.5',color='tab:brown', linewidth= '0.8', label='PO1',alpha=1,zorder=2)

[_,Jt]=readdata("Data/Ra40000/PO2/energy.asc",x_idx+1)
[_,Nu]=readdata("Data/Ra40000/PO2/energy.asc",y_idx+1)
plt.plot(Jt,Nu,marker='o',markersize='1.5',color='m', linewidth= '0.8', label='PO2',alpha=1,zorder=2)

[_,Jt]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='E1',marker='o',color='r',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E1_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E1_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='C12',marker='o',facecolors='none',color='r',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E2_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E2_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='E2$_{up}$',marker='s',color='g',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E2_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E2_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label='E2$_{low}$',marker='s',facecolors='none',color='g',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E3_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E3_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E3$_{up}$',marker='v',color='k',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E3_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E3_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E3$_{low}$',marker='v',facecolors='none',color='k',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E4_up/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E4_up/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E4$_{up}$',marker='D',color='tab:orange',zorder=2)

[_,Jt]=readdata("Data/Ra40000/E4_low/fieldconverge.asc",x_idx)
[_,Nu]=readdata("Data/Ra40000/E4_low/fieldconverge.asc",y_idx)
plt.scatter(Jt[-1],Nu[-1], label=r'E4$_{low}$',marker='D',facecolors='none',color='tab:orange',zorder=2)

plt.scatter(1,1, label='Base',marker='.',color='b',zorder=2)



plt.xlabel(r'$J_T$', fontsize=14)
plt.ylabel(r'$Nu$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

if plot_JtNu:
    xlims = plt.xlim()
    ylims = plt.ylim()
    minlim = min(xlims[0], ylims[0])
    maxlim = max(xlims[1], ylims[1])
    plt.plot([minlim, maxlim], [minlim, maxlim], '--', color='tab:blue', label=r'$Nu = J_T$', zorder=1)
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.xlabel(r'$J_T$', fontsize=14)
    plt.ylabel(r'$Nu$', fontsize=14)
    plt.savefig('Data/Ra40000/phase_portrait_JtNu.png', dpi=300, bbox_inches='tight')
elif plot_JcSh:
    plt.xlabel(r'$J_C$', fontsize=14)
    plt.ylabel(r'$Sh$', fontsize=14)
    plt.savefig('Data/Ra40000/phase_portrait_Jcsh.png', dpi=300, bbox_inches='tight')
elif plot_NuSh:
    plt.xlabel(r'$Nu$', fontsize=14)
    plt.ylabel(r'$Sh$', fontsize=14)
    # plt.legend()
    plt.legend(
        loc='right', 
        bbox_to_anchor=(1.3, 0.5),
        ncol=1, 
        frameon=False
    )
    plt.savefig('Data/Ra40000/phase_portrait_NuSh.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Compare mean profiles of DNS and ECS

# %%
from func import *
def load_data(path):
    import pandas as pd
    df = pd.read_csv(path, delimiter=', ', header=None, names=['T', 'S', 'Dens'])
    mean_T = df['T'].values
    mean_S = df['S'].values
    mean_Dens = df['Dens'].values
    return mean_T,mean_S,mean_Dens

def load_mean_data_PO(path):
    file_list = getpath(path)
    data = []
    for file in file_list:
        [y,xz_ave_T] = xz_averaged_salar(file)
        data.append(xz_ave_T)
    return np.mean(data,axis=0)



plt.figure(figsize=(3, 3))

[y,xz_ave_T] = xz_averaged_salar('Data/Ra40000/E1_up/tbest.nc')
plt.plot(xz_ave_T-y,y,color='r', linestyle = 'dashed')
[y,xz_ave_T] = xz_averaged_salar('Data/Ra40000/E2_up/tbest.nc')
plt.plot(xz_ave_T-y,y,color='g', linestyle = 'dashed')
[y,xz_ave_T] = xz_averaged_salar('Data/Ra40000/E3_up/tbest.nc')
plt.plot(xz_ave_T-y,y,color='k', linestyle = 'dashed',label=r'$\bar{T}(y)$')

[T_dns,S_dns,_] = load_data('Data/Ra40000/dns/mean_profiles_dns.csv')
plt.plot(T_dns,y[1:],color='tab:blue', linestyle = 'solid', linewidth = 3, zorder = 0)

T_PO1 = load_mean_data_PO('Data/Ra40000/PO1/t*.nc')
plt.plot(T_PO1-y,y,color='tab:brown', linestyle = 'dashed')

T_PO2 = load_mean_data_PO('Data/Ra40000/PO2/t*.nc')
plt.plot(T_PO2-y,y,color='m', linestyle = 'dashed')

plt.xlabel(r'$\overline{\langle T \rangle}_h$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
plt.xticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.yticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.gca().set_aspect('equal')
plt.grid()
plt.savefig('Data/Ra40000/MeanProfiles_temp.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# C:\Users\jms24002\AppData\Local\Temp\ipykernel_40292\918154930.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(path, delimiter=', ', header=None, names=['T', 'S', 'Dens'])
# e:\Projects\2025\ECS of sheared DDC in wall-bounded domain\Data_for_publication\func.py:75: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(path, sep='\s+')
# e:\Projects\2025\ECS of sheared DDC in wall-bounded domain\Data_for_publication\func.py:88: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(path+directory+'energy.asc', sep='\s+')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 32
# ...

# %%
plt.figure(figsize=(3, 3))

[y,xz_ave_S] = xz_averaged_salar('Data/Ra40000/E1_up/sbest.nc')
plt.plot(xz_ave_S-y,y,color='r', linestyle = 'dashed',label='E1')
[y,xz_ave_S] = xz_averaged_salar('Data/Ra40000/E2_up/sbest.nc')
plt.plot(xz_ave_S-y,y,color='g', linestyle = 'dashed',label='E2')
[y,xz_ave_S] = xz_averaged_salar('Data/Ra40000/E3_up/sbest.nc')
plt.plot(xz_ave_S-y,y,color='k', linestyle = 'dashed',label='E3')

S_PO1 = load_mean_data_PO('Data/Ra40000/PO1/s*.nc')
plt.plot(S_PO1-y,y,color='tab:brown', linestyle = 'dashed',label='PO1')

S_PO2 = load_mean_data_PO('Data/Ra40000/PO2/s*.nc')
plt.plot(S_PO2-y,y,color='m', linestyle = 'dashed',label='PO2')


[T_dns,S_dns,_] = load_data('Data/Ra40000/dns/mean_profiles_dns.csv')
plt.plot(S_dns,y[1:],color='tab:blue', linestyle = 'solid',label='DNS', linewidth = 3, zorder = 0)


plt.xlabel(r'$\overline{\langle S \rangle}_h$', fontsize=16)
plt.ylabel(r'$z$', fontsize=16)
plt.xticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.yticks([-0.5, 0, 0.5],['$-0.5$','0','0.5'],fontsize=16)
plt.gca().set_aspect('equal')
plt.grid()
plt.legend()
plt.savefig('Data/Ra40000/MeanProfiles_salt.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# # Nu Time history of dns

# %%
from func import *

plt.figure(figsize=(11, 1))

[time,Nu] = readdata("Data/Ra40000/dns/energy.asc",17)
plt.plot(time[0:],Nu[0:],'-',color='k', label='DNS')

[_,Nu]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",16)
plt.axhline(y=Nu[-1], color='r', label='E1', zorder=2)

[_,Nu]=readdata("Data/Ra40000/E2_up/fieldconverge.asc",16)
plt.axhline(y=Nu[-1], color='g', label='E2', zorder=2)

plt.xlabel(r'$t$',fontsize=14)
plt.ylabel(r'$Nu$',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim([time[0],time[10000]])
plt.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
plt.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)

plt.legend(
    # loc='right', 
    bbox_to_anchor=(0.21, 0.65),
    ncol=3, 
    frameon=False,
    fontsize=8
)

plt.savefig('Data/Ra40000/Nu_history.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Zoom in

# %%
from func import *

plt.figure(figsize=(4, 2.5))

[time,Nu] = readdata("Data/Ra40000/dns/energy.asc",17)
plt.plot(time[0:],Nu[0:],'-',color='k')

[_,Nu]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",16)
plt.axhline(y=Nu[-1], color='r', label='E1', zorder=2)

[_,Nu]=readdata("Data/Ra40000/E2_up/fieldconverge.asc",16)
plt.axhline(y=Nu[-1], color='g', label='E2', zorder=2)

plt.xlabel(r'$t$',fontsize=14)
plt.ylabel(r'$Nu$',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim([time[6300],time[6670]])
plt.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
plt.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)
plt.savefig('Data/Ra40000/Nu_zoomin.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
