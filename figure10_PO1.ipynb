# %% [markdown]
# # Plot properties of PO1 at Ra = 40000

# %%
from func import *

plot_JtNu = False
plot_JcSh = True


fontsize = 16

# PO1, T~43->44
start=0
end = -200
T=44 # 43.74

#############################################
############### plot Jt vs Nu ###############
[_,Jt_po]=readdata("Data/Ra40000/PO1/energy.asc",16)
[_,Nu_po]=readdata("Data/Ra40000/PO1/energy.asc",17)
[_,Jt_eq]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",15)
[_,Nu_eq]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",16)
Jt_po = np.append(Jt_po, Jt_po[0]) # make closed loop
Nu_po = np.append(Nu_po, Nu_po[0]) # make closed loop
plt.figure(figsize=(3, 3))
plt.plot(Jt_po,Nu_po,marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
plt.scatter(Jt_eq[-1],Nu_eq[-1],marker='o',color='r',label='E1',zorder=3)
plt.scatter(Jt_po[-2],Nu_po[-2],marker='*',color='k',zorder=3) # min Sh
plt.scatter(Jt_po[9],Nu_po[9],marker='*',color='k',zorder=3) # max Nu
plt.scatter(Jt_po[16],Nu_po[16],marker='*',color='k',zorder=3) # max Sh
plt.scatter(Jt_po[36],Nu_po[36],marker='*',color='k',zorder=3) # min Nu
ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel(r'$J_T$', fontsize=fontsize)
plt.ylabel(r'$Nu$', fontsize=fontsize)
plt.savefig('Data/Ra40000/PO1/PO1_JtNu.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()



#############################################
############### plot Js vs Sh ###############
[_,Js_po]=readdata("Data/Ra40000/PO1/energy.asc",21)
[_,Sh_po]=readdata("Data/Ra40000/PO1/energy.asc",22)
[_,Js_eq]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",20)
[_,Sh_eq]=readdata("Data/Ra40000/E1_up/fieldconverge.asc",21)
Js_po = np.append(Js_po, Js_po[0]) # make closed loop
Sh_po = np.append(Sh_po, Sh_po[0]) # make closed loop

plt.figure(figsize=(3, 3))
plt.plot(Js_po,Sh_po,marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
plt.scatter(Js_eq[-1],Sh_eq[-1],marker='o',color='r',label='E1',zorder=3)
plt.scatter(Js_po[-2],Sh_po[-2],marker='*',color='k',zorder=3) # min Sh
plt.scatter(Js_po[9],Sh_po[9],marker='*',color='k',zorder=3) # max Nu
plt.scatter(Js_po[16],Sh_po[16],marker='*',color='k',zorder=3) # max Sh
plt.scatter(Js_po[36],Sh_po[36],marker='*',color='k',zorder=3) # min Nu
ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel(r'$J_S$', fontsize=fontsize)
plt.ylabel(r'$Sh$', fontsize=fontsize)
plt.legend()
# plt.xlim([2.8215,2.823])
plt.savefig('Data/Ra40000/PO1/PO1_EQ_JcSh.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

plt.figure(figsize=(3, 3))
plt.plot(Js_po,Sh_po,marker='o',markersize='1.5',color='r', linewidth= '0.8', label='PO1',alpha=1,zorder=2)
# plt.scatter(Js_eq[-1],Sh_eq[-1],marker='o',color='r',label='E1',zorder=3)
plt.scatter(Js_po[-2],Sh_po[-2],marker='*',color='k',zorder=3) # min Sh
plt.scatter(Js_po[9],Sh_po[9],marker='*',color='k',zorder=3) # max Nu
plt.scatter(Js_po[16],Sh_po[16],marker='*',color='k',zorder=3) # max Sh
plt.scatter(Js_po[36],Sh_po[36],marker='*',color='k',zorder=3) # min Nu
ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel(r'$J_S$', fontsize=fontsize)
plt.ylabel(r'$Sh$', fontsize=fontsize)
# plt.legend()
plt.xlim([2.8215,2.823])
plt.savefig('Data/Ra40000/PO1/PO1_EQ_JcSh_onlyPO1.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
from func import *
fontsize = 16
plt.figure(figsize=(4, 3))
# PO1, T~43->44
T=44 # 43.74
start=0
end = -1

[time,Nu]=readdata("Data/Ra40000/PO1/energy.asc",17)
plt.plot(time[start:end],Nu[start:end],'k', linewidth= '1', label=r'$Nu$',zorder=2)
[time,Sh]=readdata("Data/Ra40000/PO1/energy.asc",22)
plt.plot(time[start:end],Sh[start:end],'r', linewidth= '1', label=r'$Sh$',zorder=2)
plt.xlabel(r'$t$', fontsize=fontsize)
# plt.ylabel([],fontsize=14)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.legend()
plt.savefig('Data/Ra40000/PO1/PO1_Nu_Sh_one_time_period.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
from func import *

# max Nu
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Ra40000/PO1/t10.nc',2)
plot_scalar(z,y,scalar,-0.4,0.4,False)
plt.savefig('Data/Ra40000/PO1/PO1_t_10.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# min Nu
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Ra40000/PO1/t36.nc',2)
plot_scalar(z,y,scalar,-0.4,0.4,False)
plt.savefig('Data/Ra40000/PO1/PO1_t_36.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()



# max Sh
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Ra40000/PO1/s18.nc',2)
plot_scalar(z,y,scalar,-0.37,0.37,False)
plt.savefig('Data/Ra40000/PO1/PO1_s_18.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# min Sh
plt.figure(figsize=(4, 1))
[y,z,scalar] = z_averaged_scalar('Data/Ra40000/PO1/s1.nc',2)
plot_scalar(z,y,scalar,-0.37,0.37,False)
plt.savefig('Data/Ra40000/PO1/PO1_s_1.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()
